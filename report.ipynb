# %% [markdown]
# TODOS:
#
#
# * RUN DataAnalysis.calc_precise_error for each experiment configuration
# * Create all graphs based on the resulting DataAnalyzer objects
# * Go over report
# * fix docs website

# %% [markdown]
# TODO: add yolo license
# todo: add mealpy license
# todo: add roboflow license
#
# TODO: test how many samples are needed to train yolo properly. There is a fraction parameter in the yolo config file
#
# **Introduction**
#
# * Project goals
#
# * system overview and basic terms
#     * cycle
#     * platform
#     * micro
#     * camera
#     * bbox predictor
#     * controller
#     * timing-digram
#     * etc...
#
# * basic requirements
#
# **Code Structure**
#
# * introduce each namespace
#     * minor elaboration on some important classes
#
# * Project workflow
#     * elaborate on the role of each notebook
#
# **Results**
#
# * our proposed solution
#
# * run few experiments and evaluate on them
# * create videos depicting system predictions
#     * create micro-view video
#     * use VLC to see whole world and how the system behaves
#
# * test how many samples from each experiment suffices
# * Use precise loss for plots
# * measure timing and provide rough estimates on timings
# * reproducibility is key!
#
# * project installation:
#     * make sure requirements are good
#     * install the project in clean environment
#     * create .sh file that installs environment
#
# * present warm speed plots perhaps
#
# * present different approaches we tried
#     * PolyFit
#     * MLP Controller
#     * Optimal Controller
#     * Baseline CSV Controller
#
# **Conclusions**
#
# * which timingConfig setups age good for which scenario
#     * present optimal results to understand the bounds and whats actually possible and not
#     * for 60x micor we need to split imaging into two 100ms halves
#     * for 40x micro we can perform 200ms imaging in one go
