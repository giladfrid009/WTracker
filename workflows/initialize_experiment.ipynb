# %% [markdown]
# # Experiment Initialization

# %% [markdown]
# After capturing an experiment video (or series of frames), in order to run the system simulation on it, one must first initialize this experiment.
# The experiment initialization process is the process in which the YOLO model predicts the worm head position in every frame of the experiment video.
# These worm head positions are afterwards logged into a file.
#
# This initialization step is designed to address two important issues:
# 1.  Running a simulation on a sequence of frames (images) that are read from the disk is slow, since the process loading large amount of images from the disk is relatively slow.
# 2.  Given an image, running the YOLO model on that image and detecting worm's head position is also relatively slow.
#
# Therefore, instead of performing the above two steps every time we want to run a simulation on some experiment, we instead perform these steps only *ONCE*. On each frame, we run the YOLO predictor and detect the worm's head position. Afterwards, we log the detected head coordinates into a log file (bboxes.csv). As result, consequent simulations of this experiment can simply read the log file to obtain worm head positions, instead of running YOLO again. Also, loading the images fro the disk is no longer required, since all the relevant information is in the log.

# %%
# fix imports
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from wtracker.sim import *
from wtracker.sim.sim_controllers import *
from wtracker.utils.path_utils import Files, join_paths
from wtracker.utils.gui_utils import UserPrompt
from wtracker.utils.frame_reader import FrameReader
import cv2 as cv
# Out:
# c:\Users\slevylab\AppData\Local\miniforge3\envs\bio_proj\Lib\site-packages\onnxruntime\capi\onnxruntime_validation.py:26: UserWarning: Unsupported Windows version (11). ONNX Runtime supports Windows 10 and above, only.
#   warnings.warn(

# %% [markdown]
# ### Input and output directories

# %%
################################ User Input ################################

# define the path to the folder containing the frame images of the experiment
# if none, the user will be prompted to select the folder
images_folder = None

# define the path into which the analysis of the experiment will be saved,
# including bounding box detections at each frame (bboxes.csv)
# if none, the user will be prompted to select the folder
output_folder = None

############################################################################

if images_folder is None:
    images_folder = UserPrompt.open_directory("Select the folder containing the frame images")

if output_folder is None:
    output_folder = UserPrompt.open_directory("Select the folder to save the output analysis to")

print(f"input images folder: {images_folder}")
print(f"output folder: {output_folder}")
# Out:
# input images folder: D:/Guy_Gilad/Guy_Gilad_3
# output folder: D:/Guy_Gilad/Exp3_GuyGilad/yolo_log

# %%
from typing import Callable, Union

################################ User Input ################################

# select file extension of the frame images
frame_file_extension = "Bmp"

# define the function by which the image files are ordered. 
# The function should take a string as input and return a string or an integer.
filename_sorting_func: Callable[[str], Union[str, int]] = lambda name: int(name.split("-")[-1].split(".")[0])

############################################################################

# read the frame images from the provided directory
files = Files(
    extension=frame_file_extension,
    directory=images_folder,
    sorting_key=filename_sorting_func,
    scan_dirs=False,
    return_full_path=False,
)

frame_files = list(files)
reader = FrameReader(images_folder, frame_files, read_format=cv.IMREAD_GRAYSCALE)

# %% [markdown]
# ### Experiment, timing settings and YOLO configuration

# %%
################################ User Input ################################

# create the experiment config
# this configuration differs between different experiments
experiment_config = ExperimentConfig.from_frame_reader(
    reader,
    name="experiment3",
    frames_per_sec=60,
    px_per_mm=88,
    init_position=(132, 1032),
)

# initialize the timing configuration
# changing this config changes the simulation settings, should remain the same
# between different experiments
time_config = TimingConfig(
    imaging_time_ms=200,
    pred_time_ms=40,
    moving_time_ms=50,
    camera_size_mm=(4, 4),
    micro_size_mm=(0.32, 0.32),
    experiment_config=experiment_config,
)

############################################################################

# initialize logging settings
log_config = LogConfig(
    root_folder=output_folder,
    save_mic_view=False,  # whether to save images of the microscope view
    save_cam_view=False,  # whether to save images of the camera view
    save_wrm_view=True,  # whether to save images of the detected worms. These images are later used to calculate precise error during analysis. can be disabled to save disk space.
    save_err_view=True,  # whether to save camera view of frames when no object is detected
    bbox_file_name="init_bboxes.csv", 
)

# %%
################################ User Input ################################

# specify inference device for the YOLO model. If GPU is available, it is recommended to select `cuda` option
device = "cpu"  # cpu or cuda

# specify the path to the YOLO model weights.
# If no path is specified, the user will be prompted to select a file.
yolo_model_path = None

############################################################################

if yolo_model_path is None:
    yolo_model_path = UserPrompt.open_file("Select YOLO model", [("pytorch file", "*.pt"), ("ONNX model", "*.onnx")])

# create the YOLO configuration
yolo_config = YoloConfig(
    model_path=yolo_model_path,
    device=device,
    verbose=True,  # controls the verbosity of the YOLO predictor. No need to be set to True since there is a progress bar anyways.
    pred_kwargs={
        "imgsz": 384,  # imgsz should be the same size on which the model was trained.
        "conf": 0.1,  # minimum confidence threshold for detection of worm head.
    },
)

# %%
# save config files
experiment_config.save_json(join_paths(output_folder, "exp_config.json"))
log_config.save_json(join_paths(output_folder, "log_config.json"))
time_config.save_json(join_paths(output_folder, "time_config.json"))
yolo_config.save_json(join_paths(output_folder, "yolo_config.json"))

# %% [markdown]
# ### Run YoloController and save log file
#
# The YoloController expects the simulator to receive experiment images as input.
# This controller runs the YOLO predictor on the input images and predicts the bounding box around worm's head in each such image.
#
# Note, that executing the cells below might take very long time, up to few hours.

# %%
# create YoloController of the simulation that runs in real time and detects worms heap positions from the input frames
yolo_controller = YoloController(time_config, yolo_config)

# wrap the YoloController with a LoggingController to log the simulation data
# this controller logs the detected head positions into bboxes.csv file, which could be used afterwards
# by different controllers, without the need to run the YOLO model again
controller = LoggingController(yolo_controller, log_config)

# %%
# create motor controller which controls the motion of the platform 
motor_controller = SineMotorController(time_config)

# create the simulator
sim = Simulator(
    time_config,
    experiment_config,
    controller,
    reader=reader,
    motor_controller=motor_controller,
)

# %%
# run simulation and save log results
sim.run(visualize=False, wait_key=False)
# Out:
# Simulation Progress:   0%|          | 0/4333 [00:00<?, ?cycle/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading D:\Guy_Gilad\Bio-Proj\data\yolov8s-datav5-best.onnx for ONNX Runtime inference...
# c:\Users\slevylab\AppData\Local\miniforge3\envs\bio_proj\Lib\site-packages\torch\cuda\__init__.py:141: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at C:\cb\pytorch_1000000000000\work\c10\cuda\CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# 0: 384x384 1 Head, 37.5ms
# Speed: 0.0ms preprocess, 37.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 357.0ms
# Speed: 1.9ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.3ms
# Speed: 1.0ms preprocess, 25.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 323.5ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 334.4ms
# Speed: 0.6ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 17.3ms
# Speed: 1.3ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 335.5ms
# Speed: 0.7ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 340.7ms
# Speed: 0.9ms preprocess, 22.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.9ms
# Speed: 1.2ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 328.9ms
# Speed: 0.7ms preprocess, 21.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 33.8ms
# Speed: 0.0ms preprocess, 33.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 344.0ms
# Speed: 1.7ms preprocess, 22.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 27.0ms
# Speed: 1.0ms preprocess, 27.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 329.9ms
# Speed: 0.8ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 360.3ms
# Speed: 1.5ms preprocess, 24.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 35.0ms
# Speed: 1.0ms preprocess, 35.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 334.7ms
# Speed: 0.2ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 37.1ms
# Speed: 0.0ms preprocess, 37.1ms inference, 22.8ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 337.4ms
# Speed: 0.9ms preprocess, 22.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 373.0ms
# Speed: 0.7ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 39.2ms
# Speed: 0.0ms preprocess, 39.2ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 324.7ms
# Speed: 0.8ms preprocess, 21.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 348.7ms
# Speed: 1.5ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 37.0ms
# Speed: 0.0ms preprocess, 37.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 342.1ms
# Speed: 0.9ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 26.8ms
# Speed: 0.0ms preprocess, 26.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 322.5ms
# Speed: 0.7ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 309.0ms
# Speed: 0.9ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 335.4ms
# Speed: 0.7ms preprocess, 22.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 347.9ms
# Speed: 1.0ms preprocess, 23.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 32.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 336.7ms
# Speed: 1.0ms preprocess, 22.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 346.5ms
# Speed: 1.4ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 321.8ms
# Speed: 0.8ms preprocess, 21.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.3ms
# Speed: 1.0ms preprocess, 24.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 339.4ms
# Speed: 1.0ms preprocess, 22.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 343.8ms
# Speed: 1.4ms preprocess, 22.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 338.1ms
# Speed: 1.3ms preprocess, 22.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 358.2ms
# Speed: 0.8ms preprocess, 23.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.6ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 346.8ms
# Speed: 0.7ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 34.5ms
# Speed: 0.0ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 334.4ms
# Speed: 1.8ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 358.9ms
# Speed: 0.7ms preprocess, 23.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.3ms
# Speed: 1.0ms preprocess, 23.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 382.7ms
# Speed: 0.4ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 343.1ms
# Speed: 0.7ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 34.0ms
# Speed: 0.0ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 365.5ms
# Speed: 0.4ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 38.6ms
# Speed: 0.0ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 362.0ms
# Speed: 0.8ms preprocess, 24.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.2ms
# Speed: 1.0ms preprocess, 24.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 347.8ms
# Speed: 1.7ms preprocess, 23.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 15.6ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 330.7ms
# Speed: 1.0ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 357.0ms
# Speed: 1.6ms preprocess, 23.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.3ms
# Speed: 15.2ms preprocess, 24.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 371.2ms
# Speed: 1.2ms preprocess, 24.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 27.7ms
# Speed: 0.0ms preprocess, 27.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 336.9ms
# Speed: 1.2ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 28.2ms
# Speed: 0.0ms preprocess, 28.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 328.2ms
# Speed: 0.8ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 26.9ms
# Speed: 0.0ms preprocess, 26.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 321.3ms
# Speed: 0.9ms preprocess, 21.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 18.7ms
# Speed: 1.0ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 383.0ms
# Speed: 0.7ms preprocess, 25.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 34.6ms
# Speed: 0.0ms preprocess, 34.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 327.3ms
# Speed: 0.7ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 19.7ms
# Speed: 0.0ms preprocess, 19.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 338.2ms
# Speed: 0.2ms preprocess, 22.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 32.8ms
# Speed: 0.0ms preprocess, 32.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 363.8ms
# Speed: 0.2ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 340.9ms
# Speed: 1.8ms preprocess, 22.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 29.6ms
# Speed: 0.0ms preprocess, 29.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 365.3ms
# Speed: 0.9ms preprocess, 24.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 29.5ms
# Speed: 0.0ms preprocess, 29.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 346.3ms
# Speed: 1.2ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 32.4ms
# Speed: 0.0ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 330.4ms
# Speed: 0.1ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 19.9ms
# Speed: 0.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 321.0ms
# Speed: 0.5ms preprocess, 21.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 22.7ms
# Speed: 15.1ms preprocess, 22.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 333.9ms
# Speed: 1.7ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 36.0ms
# Speed: 0.0ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 344.5ms
# Speed: 1.2ms preprocess, 23.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 373.8ms
# Speed: 0.8ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 340.9ms
# Speed: 1.6ms preprocess, 22.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 29.1ms
# Speed: 0.0ms preprocess, 29.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 343.8ms
# Speed: 1.7ms preprocess, 22.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 347.3ms
# Speed: 1.7ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 349.4ms
# Speed: 2.0ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 19.4ms
# Speed: 0.0ms preprocess, 19.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 346.7ms
# Speed: 1.5ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 383.9ms
# Speed: 0.8ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 349.0ms
# Speed: 2.1ms preprocess, 23.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.7ms
# Speed: 1.0ms preprocess, 24.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 349.4ms
# Speed: 0.9ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 32.6ms
# Speed: 0.0ms preprocess, 32.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 356.2ms
# Speed: 0.7ms preprocess, 23.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 30.2ms
# Speed: 0.0ms preprocess, 30.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 334.6ms
# Speed: 1.1ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 35.1ms
# Speed: 0.0ms preprocess, 35.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 338.8ms
# Speed: 0.7ms preprocess, 22.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 351.2ms
# Speed: 0.9ms preprocess, 23.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 35.9ms
# Speed: 0.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 345.9ms
# Speed: 1.4ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 39.9ms
# Speed: 0.0ms preprocess, 39.9ms inference, 23.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 318.1ms
# Speed: 1.3ms preprocess, 21.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 382.1ms
# Speed: 0.5ms preprocess, 25.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 38.6ms
# Speed: 0.0ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 345.8ms
# Speed: 1.5ms preprocess, 23.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 319.3ms
# Speed: 0.7ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 319.0ms
# Speed: 0.8ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 30.5ms
# Speed: 0.0ms preprocess, 30.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 343.3ms
# Speed: 0.7ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.4ms
# Speed: 16.2ms preprocess, 25.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 342.2ms
# Speed: 1.1ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.2ms
# Speed: 1.0ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 335.0ms
# Speed: 0.8ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 364.5ms
# Speed: 2.0ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.1ms
# Speed: 0.0ms preprocess, 25.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 343.1ms
# Speed: 0.6ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 365.0ms
# Speed: 0.9ms preprocess, 24.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 378.7ms
# Speed: 0.5ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 35.5ms
# Speed: 0.0ms preprocess, 35.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 370.8ms
# Speed: 0.5ms preprocess, 24.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 353.2ms
# Speed: 0.8ms preprocess, 23.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 374.0ms
# Speed: 0.7ms preprocess, 24.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 364.3ms
# Speed: 0.2ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 28.2ms
# Speed: 1.0ms preprocess, 28.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 349.3ms
# Speed: 0.8ms preprocess, 23.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 35.7ms
# Speed: 0.0ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 392.4ms
# Speed: 1.3ms preprocess, 26.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 22.3ms
# Speed: 15.6ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 342.4ms
# Speed: 0.3ms preprocess, 22.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 36.2ms
# Speed: 0.0ms preprocess, 36.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.5ms
# Speed: 0.8ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 15.9ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 356.1ms
# Speed: 1.0ms preprocess, 23.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 21.5ms
# Speed: 9.0ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 323.4ms
# Speed: 0.7ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.9ms
# Speed: 1.0ms preprocess, 23.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 342.8ms
# Speed: 0.2ms preprocess, 22.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 346.0ms
# Speed: 2.2ms preprocess, 23.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 22.7ms
# Speed: 1.0ms preprocess, 22.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# ...
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 324.4ms
# Speed: 1.1ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.8ms
# Speed: 0.0ms preprocess, 25.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 326.8ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.5ms
# Speed: 1.0ms preprocess, 23.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 324.6ms
# Speed: 1.1ms preprocess, 21.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 23.8ms
# Speed: 1.0ms preprocess, 23.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 341.3ms
# Speed: 0.7ms preprocess, 22.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 334.5ms
# Speed: 1.2ms preprocess, 22.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.6ms
# Speed: 1.0ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 344.1ms
# Speed: 0.9ms preprocess, 22.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 327.2ms
# Speed: 0.9ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.2ms
# Speed: 1.0ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 330.5ms
# Speed: 1.1ms preprocess, 22.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 326.8ms
# Speed: 0.7ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.8ms
# Speed: 0.0ms preprocess, 25.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 324.5ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 332.3ms
# Speed: 0.3ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.4ms
# Speed: 1.1ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 327.9ms
# Speed: 0.7ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 327.3ms
# Speed: 1.2ms preprocess, 21.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 26.5ms
# Speed: 0.0ms preprocess, 26.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 323.8ms
# Speed: 0.7ms preprocess, 21.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 27.2ms
# Speed: 1.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.5ms
# Speed: 1.1ms preprocess, 22.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.2ms
# Speed: 0.8ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 20.8ms
# Speed: 1.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.1ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 328.2ms
# Speed: 0.8ms preprocess, 21.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 334.1ms
# Speed: 0.4ms preprocess, 22.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.0ms
# Speed: 1.6ms preprocess, 22.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 29.8ms
# Speed: 0.0ms preprocess, 29.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 343.4ms
# Speed: 0.7ms preprocess, 22.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.1ms
# Speed: 1.0ms preprocess, 25.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 325.5ms
# Speed: 0.8ms preprocess, 21.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.8ms
# Speed: 1.0ms preprocess, 24.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 332.3ms
# Speed: 0.9ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 27.2ms
# Speed: 0.0ms preprocess, 27.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 325.0ms
# Speed: 0.8ms preprocess, 21.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 331.8ms
# Speed: 1.6ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 329.6ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 24.9ms
# Speed: 1.0ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 330.2ms
# Speed: 0.9ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 330.8ms
# Speed: 0.9ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
#
# 0: 384x384 1 Head, 1: 384x384 1 Head, 2: 384x384 1 Head, 3: 384x384 1 Head, 4: 384x384 1 Head, 5: 384x384 1 Head, 6: 384x384 1 Head, 7: 384x384 1 Head, 8: 384x384 1 Head, 9: 384x384 1 Head, 10: 384x384 1 Head, 11: 384x384 1 Head, 12: 384x384 1 Head, 13: 384x384 1 Head, 14: 384x384 1 Head, 329.9ms
# Speed: 1.1ms preprocess, 22.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 384)

# %% [markdown]
# ### Extract the background of the experiment

# %%
from wtracker.dataset.bg_extractor import BGExtractor

extractor = BGExtractor(reader)

################################ User Input ################################

# calculate the background of the experiment
background = extractor.calc_background(
    num_probes=1000,  # num frames from from which the background will be calculated
    sampling="uniform",  # sampling method for the frames. Options: "uniform", "median"
    method="median",  # method to calculate the background. Options: "mean", "median"
)

############################################################################

# %%
import numpy as np

# save the background image
background_path = join_paths(output_folder, "background")
np.save(file=background_path, arr=background)
